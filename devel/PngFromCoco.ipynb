# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from skimage.draw import polygon
import skimage.io
from pathlib import Path
from loguru import logger


class AnnotationTOmask:
    def __init__(self, annotation_file):
        # load dataset
        print('loading annotations ...')
        dataset = json.load(open(annotation_file, 'r'))
        print('annotations loaded!')

        # creating index
        print('creating index...')
        imgToAnns = {ann['image_id']: [] for ann in dataset['annotations']}
        anns =      {ann['id']:       [] for ann in dataset['annotations']}
        for ann in dataset['annotations']:
            imgToAnns[ann['image_id']] += [ann]
            anns[ann['id']] = ann

        imgs      = {im['id']: {} for im in dataset['images']}
        for img in dataset['images']:
            imgs[img['id']] = img

        cats = []
        catToImgs = []
        cats = {cat['id']: [] for cat in dataset['categories']}
        for cat in dataset['categories']:
            cats[cat['id']] = cat
        catToImgs = {cat['id']: [] for cat in dataset['categories']}
        for ann in dataset['annotations']:
            catToImgs[ann['category_id']] += [ann['image_id']]

        print('index created!')

        # create class members
        self.anns = anns
        self.imgToAnns = imgToAnns
        self.catToImgs = catToImgs
        self.imgs = imgs
        self.cats = cats
        self.dataset = dataset


    def getAnnIds(self, imgIds, catIds):
        """
        Get ann ids for given cats from all images
        """
        imgIds = imgIds if type(imgIds) == list else [imgIds]
        catIds = catIds if type(catIds) == list else [catIds]

        if not len(imgIds) == 0:
            anns = sum([self.imgToAnns[imgId] for imgId in imgIds if imgId in self.imgToAnns],[])
        else:
            anns = self.dataset['annotations']
        anns = anns if len(catIds)  == 0 else [ann for ann in anns if ann['category_id'] in catIds]
        ids = [ann['id'] for ann in anns]

        return ids

    def getCatIds(self, catNms=[], catIds=[]):
        """ 
        get integer array of cat ids for given cat names, given cat ids
        """
        if len(catNms) == len(catIds) == 0:
            cats = self.dataset['categories']
        else:
            print('+++++++++++++++++++++')
            cats = self.dataset['categories']
            cats = cats if len(catNms) == 0 else [cat for cat in cats if cat['name']          in catNms]
            cats = cats if len(catIds) == 0 else [cat for cat in cats if cat['id']            in catIds]
        ids = [cat['id'] for cat in cats]
        return ids

    def getImgIds(self, imgIds=[], catIds=[]):
        '''
        return an integer array of img ids for given ids with all given cats
        '''
        ids = set(imgIds)
        for catId in catIds:
            if len(ids) == 0:
                ids = set(self.catToImgs[catId])
            else:
                ids &= set(self.catToImgs[catId])
        return list(ids)

    def loadAnns(self, ids=[]):
        """
        loaded ann objects for integer ids specifying annotations
        """
        if type(ids) == list:
            return [self.anns[id] for id in ids]
        elif type(ids) == int:
            return [self.anns[ids]]

    def loadImgs(self, ids):
        """
        Load loaded img objects with the specified ids.
        """
        return [self.imgs[ids]]

    def getSeg(self, anns):
        """
        get annotations segmentatins
        """
        if len(anns) == 0:
            print('no annotations found')
            return 0

        S = []
        for ann in anns:
            for seg in ann['segmentation']:
                S.append(seg)
        return S

    def segToMask(self, S, h, w ):
         """
         Convert polygon segmentation to binary mask.
           S: polygon segmentation mask, h: target mask height, w: target mask width
         """
         M = np.zeros((h,w))
         for s in S:
             N = len(s)
             rr, cc = polygon(np.array(s[1:N:2]), np.array(s[0:N:2])) # (y, x)
             M[rr, cc] = 1
         return M


def coco_to_mask(coco_filename, output_dir, organ, voxelsize_mm=None, output_type="JPG", show=False, name_prefix="MaskOfPig_"):
    """
    :param coco_filename: coco_filename must include not only name of Coco file, but also it`s full direction (location) in your PC
    :param output_dir: is used for controll output direction (location) in your PC
    :param organ: name of segmentation part rom what we want have mask ""
    :param voxelsize_mm:
    :param output_type: type of "Save fail" of our program| results]
    :param show:
    :return:
    """
    #file_path = 'task_cell track 20200226-dii-30las-2pre1-2020_10_26_13_28_36-coco 1.0/annotations/instances_default.json'

    file_path = coco_filename
    import datetime
    t0 = datetime.datetime.now()
    cv_an = AnnotationTOmask(file_path)
    t1 = datetime.datetime.now()
    cv_an1=cv_an.getImgIds()
    t2 = datetime.datetime.now()
    logger.debug(f"{t1 - t0}, {t2 - t1}")
    logger.debug('getImgIds', cv_an1)
    # extract the region we want to mask ( Right Kidny,  Liver)

    #catIds = cv_an.getCatIds(catNms=['cell'])
    catIds = cv_an.getCatIds(catNms=[organ])
    #catIds = cv_an.getCatIds(catNms=['Liver'])
    #catIds = cv_an.getCatIds(catNms=['Left Kidney'])

    logger.debug('catIds', catIds)
    imgIds = cv_an.getImgIds(catIds=catIds)
    if len(imgIds) == 0:
        logger.warning(f"Label '{organ}' not found.")
    logger.debug(f'imgIds={imgIds}')
    Path(output_dir).mkdir(parents=True, exist_ok=True)

    #TODO allow storing into one file
    #  imgName = cv_an.dataset['images'][0]
    #  M = np.zeros([imgName['width'], imgName['height'],len(cv_an["images"])])
    #  ...

    # create empty files
    for imgName in cv_an.dataset['images']:
        logger.debug(f'imgName={imgName}')
        M = np.zeros([imgName['width'], imgName['height']])
        image_path = Path(output_dir) / (name_prefix+Path(imgName['file_name']).name+'.'+output_type)
        logger.debug(f"image_path={image_path}")
        skimage.io.imsave(image_path, np.uint8(M), check_contrast=False)
        # plt.imsave(image_path, np.uint8(M), cmap = 'gray')

    # rewrite images with label
    for im in imgIds:
        logger.debug(f"iM{im}")
        imgName = cv_an.loadImgs(im)[0]
        anns_ids = cv_an.getAnnIds(imgIds=imgName['id'], catIds=catIds)
        anns = cv_an.loadAnns(anns_ids)
        S = cv_an.getSeg(anns)
        M = cv_an.segToMask(S, imgName['width'], imgName['height']) * 255
        if show:
            plt.figure()
            plt.imshow(M)
            plt.show()
            plt.close()
        # image_path = Path(output_dir) / ('MaskOfPIG_'+str(imgName['file_name'])+'.'+output_type)
        image_path = Path(output_dir) / (name_prefix+Path(imgName['file_name']).name+'.'+output_type)
        logger.debug(image_path)
        un = np.unique(M)
        if len(un) < 2:
            logger.warning(f"No data found in annotation {imgName['file_name']}")
        skimage.io.imsave(image_path, np.uint8(M), check_contrast=False)
        plt.imsave(image_path, np.uint8(M), cmap='gray')

    logger.debug('Done')

# %%
Coco_Path="D:/Experimenty/Masky/Ucitel/Validace.json"
Output_Path="D:/Experimenty/Masky/Validace/Liver"
organ="Liver"
coco_to_mask1=coco_to_mask(Coco_Path, Output_Path, organ, voxelsize_mm=None, output_type="PNG", show=False, name_prefix="MaskOfPig_")
# Out:
# 2023-05-18 01:16:17.996 | DEBUG    | __main__:coco_to_mask:152 - 0:00:00.015523, 0:00:00
# 2023-05-18 01:16:17.997 | DEBUG    | __main__:coco_to_mask:153 - getImgIds
# 2023-05-18 01:16:17.998 | DEBUG    | __main__:coco_to_mask:161 - catIds
# 2023-05-18 01:16:17.998 | DEBUG    | __main__:coco_to_mask:165 - imgIds=[407, 408, 409, 410, 411, 505, 508, 506, 507, 503, 12660, 12661, 12662, 12663, 12664, 12665, 12666, 12667, 12668, 12669, 12670, 12671, 12672, 12673, 12674, 12675, 12676, 12677, 12678, 12679, 12680, 12681, 12682, 12683, 12684, 12685, 12686, 12687, 12688, 12689, 12690, 12691, 12692, 12693, 12694, 12695, 12696, 12697, 12698, 12699, 12700, 12701, 12702, 12703, 12704, 12705, 12706, 12707, 12708, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 509, 510, 511, 12899, 12900, 12901, 12902, 12903, 12904, 12905, 12906, 12907, 12908, 12909, 12910, 12911, 12912, 12913, 12914, 12915, 12916, 12917, 12918, 12919, 12920, 13155, 13156, 13157, 13158, 13159, 13160, 13161, 13162, 13163, 13164, 13165, 13166, 13167, 13168, 13169, 13170, 13171, 13172, 13173, 13174, 13175, 13176, 13177, 13178, 13179, 13180, 13181, 13182, 13183, 13184, 13185, 13186, 13187, 13188, 13189, 13190, 13191, 13192, 13193, 13194, 13195, 13196, 13197, 13198, 13199, 13200, 13201, 13202, 13203, 13204, 13205, 13206, 13207, 13208, 13209, 13210, 13211, 13212, 13213, 13214, 13215, 13216, 13217, 13218, 13219, 13220, 13221, 13222, 13223, 13224, 13225, 13226, 13227, 13228, 13229, 13230, 13231, 13232, 13233, 13234, 13235, 13236, 13237, 13238, 13239, 13240, 13241, 13242, 13243, 13244, 13245, 13246, 13247, 13248, 13249, 13250, 13251, 13252, 13253, 13254, 13255, 13256, 13257, 13258, 13259, 13260, 13261, 13262, 13263, 13264, 13265, 13266, 13267, 13268, 13269, 13270, 13271, 13272, 13273, 986, 987, 988, 989, 990, 991, 992, 993, 994, 995, 996, 997, 998, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 13274, 13275, 13276, 13277, 13278, 13279, 13280, 13281, 13282, 13283, 13284, 13285, 13286, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 504, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406]
# 2023-05-18 01:16:18.000 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12447, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00881.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.000 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00881.jpg.PNG
# 2023-05-18 01:16:18.004 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12448, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00880.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.005 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00880.jpg.PNG
# 2023-05-18 01:16:18.008 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12449, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00879.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.008 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00879.jpg.PNG
# 2023-05-18 01:16:18.012 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12450, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00878.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.013 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00878.jpg.PNG
# 2023-05-18 01:16:18.017 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12451, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00877.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.017 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00877.jpg.PNG
# 2023-05-18 01:16:18.020 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12452, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00876.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.021 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00876.jpg.PNG
# 2023-05-18 01:16:18.024 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12453, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00875.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.024 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00875.jpg.PNG
# 2023-05-18 01:16:18.028 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12454, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00874.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.028 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00874.jpg.PNG
# 2023-05-18 01:16:18.032 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12455, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00873.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.033 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00873.jpg.PNG
# 2023-05-18 01:16:18.037 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12456, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00872.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.037 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00872.jpg.PNG
# 2023-05-18 01:16:18.040 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12457, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00871.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.041 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00871.jpg.PNG
# 2023-05-18 01:16:18.044 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12458, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00870.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.045 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00870.jpg.PNG
# loading annotations ...
# annotations loaded!
# creating index...
# index created!
# +++++++++++++++++++++
# 2023-05-18 01:16:18.436 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12459, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00869.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.437 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00869.jpg.PNG
# 2023-05-18 01:16:18.442 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12460, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00868.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.442 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00868.jpg.PNG
# 2023-05-18 01:16:18.446 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12461, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00867.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.447 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00867.jpg.PNG
# 2023-05-18 01:16:18.454 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12462, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00866.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.455 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00866.jpg.PNG
# 2023-05-18 01:16:18.458 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12463, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00865.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.459 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00865.jpg.PNG
# 2023-05-18 01:16:18.463 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12464, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00864.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.464 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00864.jpg.PNG
# 2023-05-18 01:16:18.469 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12465, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00863.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.469 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00863.jpg.PNG
# 2023-05-18 01:16:18.473 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12466, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00862.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.474 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00862.jpg.PNG
# 2023-05-18 01:16:18.477 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12467, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00861.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.478 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00861.jpg.PNG
# 2023-05-18 01:16:18.483 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12468, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00860.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.484 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00860.jpg.PNG
# 2023-05-18 01:16:18.488 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12469, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00859.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.490 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00859.jpg.PNG
# 2023-05-18 01:16:18.494 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12470, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00858.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.495 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00858.jpg.PNG
# 2023-05-18 01:16:18.499 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12471, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00627.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.500 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00627.jpg.PNG
# 2023-05-18 01:16:18.504 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12472, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00626.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.504 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00626.jpg.PNG
# 2023-05-18 01:16:18.508 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12473, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00625.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.509 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00625.jpg.PNG
# 2023-05-18 01:16:18.512 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12474, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00624.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.513 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00624.jpg.PNG
# 2023-05-18 01:16:18.517 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12475, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00623.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.518 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00623.jpg.PNG
# 2023-05-18 01:16:18.522 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12476, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00622.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.523 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00622.jpg.PNG
# 2023-05-18 01:16:18.527 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12477, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00621.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.527 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00621.jpg.PNG
# 2023-05-18 01:16:18.531 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12478, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00620.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.532 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00620.jpg.PNG
# 2023-05-18 01:16:18.536 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12479, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00619.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.536 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00619.jpg.PNG
# 2023-05-18 01:16:18.540 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12480, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00618.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.541 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00618.jpg.PNG
# 2023-05-18 01:16:18.545 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12481, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00617.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.545 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00617.jpg.PNG
# 2023-05-18 01:16:18.550 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12482, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00616.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.550 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00616.jpg.PNG
# 2023-05-18 01:16:18.554 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12483, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00615.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.555 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00615.jpg.PNG
# 2023-05-18 01:16:18.559 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12484, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00614.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.559 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00614.jpg.PNG
# 2023-05-18 01:16:18.563 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12485, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00613.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.564 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00613.jpg.PNG
# 2023-05-18 01:16:18.568 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12486, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00612.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.569 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00612.jpg.PNG
# 2023-05-18 01:16:18.572 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12487, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00611.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.573 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00611.jpg.PNG
# 2023-05-18 01:16:18.577 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12488, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00610.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.577 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00610.jpg.PNG
# 2023-05-18 01:16:18.582 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12489, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00609.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.584 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00609.jpg.PNG
# 2023-05-18 01:16:18.588 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12490, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00608.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.589 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00608.jpg.PNG
# 2023-05-18 01:16:18.592 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12491, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00607.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.593 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00607.jpg.PNG
# 2023-05-18 01:16:18.598 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12492, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00606.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.598 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00606.jpg.PNG
# 2023-05-18 01:16:18.602 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12493, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00605.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.603 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00605.jpg.PNG
# 2023-05-18 01:16:18.607 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12494, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00604.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.608 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00604.jpg.PNG
# 2023-05-18 01:16:18.611 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12495, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00603.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.612 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00603.jpg.PNG
# 2023-05-18 01:16:18.616 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12496, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00602.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.617 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00602.jpg.PNG
# 2023-05-18 01:16:18.621 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12497, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00601.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.622 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00601.jpg.PNG
# 2023-05-18 01:16:18.625 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12498, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00600.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.626 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00600.jpg.PNG
# 2023-05-18 01:16:18.631 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12499, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00599.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.631 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00599.jpg.PNG
# 2023-05-18 01:16:18.635 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12500, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00598.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.636 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00598.jpg.PNG
# 2023-05-18 01:16:18.641 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12501, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00597.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.641 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00597.jpg.PNG
# 2023-05-18 01:16:18.645 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12502, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00596.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.646 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00596.jpg.PNG
# 2023-05-18 01:16:18.649 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12503, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00595.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.650 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00595.jpg.PNG
# 2023-05-18 01:16:18.655 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12504, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00594.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.655 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00594.jpg.PNG
# 2023-05-18 01:16:18.659 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12505, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00593.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.660 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00593.jpg.PNG
# 2023-05-18 01:16:18.664 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12506, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00592.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.665 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00592.jpg.PNG
# 2023-05-18 01:16:18.669 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12507, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00591.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.669 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00591.jpg.PNG
# 2023-05-18 01:16:18.673 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12508, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00590.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.674 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00590.jpg.PNG
# 2023-05-18 01:16:18.678 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12509, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00589.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.678 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00589.jpg.PNG
# 2023-05-18 01:16:18.684 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12510, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00588.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.685 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00588.jpg.PNG
# 2023-05-18 01:16:18.689 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12511, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00587.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.690 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00587.jpg.PNG
# 2023-05-18 01:16:18.694 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12512, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00586.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.694 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00586.jpg.PNG
# 2023-05-18 01:16:18.700 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12513, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00585.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.700 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00585.jpg.PNG
# 2023-05-18 01:16:18.704 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12514, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00584.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.705 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00584.jpg.PNG
# 2023-05-18 01:16:18.708 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12515, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00583.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.709 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00583.jpg.PNG
# 2023-05-18 01:16:18.713 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12516, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00582.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.714 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00582.jpg.PNG
# 2023-05-18 01:16:18.717 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12517, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00581.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.718 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00581.jpg.PNG
# 2023-05-18 01:16:18.722 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12518, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00580.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.723 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00580.jpg.PNG
# 2023-05-18 01:16:18.727 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12519, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00579.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.727 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00579.jpg.PNG
# 2023-05-18 01:16:18.731 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12520, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00578.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.732 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00578.jpg.PNG
# 2023-05-18 01:16:18.736 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12521, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00577.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.737 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00577.jpg.PNG
# 2023-05-18 01:16:18.741 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12522, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00576.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.741 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00576.jpg.PNG
# 2023-05-18 01:16:18.745 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12523, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00575.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.746 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00575.jpg.PNG
# 2023-05-18 01:16:18.750 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12524, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00574.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.751 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00574.jpg.PNG
# 2023-05-18 01:16:18.754 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12525, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00573.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.755 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00573.jpg.PNG
# 2023-05-18 01:16:18.759 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12526, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00572.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.759 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00572.jpg.PNG
# 2023-05-18 01:16:18.763 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12527, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00571.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.764 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00571.jpg.PNG
# 2023-05-18 01:16:18.768 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12528, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00570.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.769 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00570.jpg.PNG
# 2023-05-18 01:16:18.773 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12529, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00569.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.773 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00569.jpg.PNG
# 2023-05-18 01:16:18.778 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12530, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00568.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.778 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00568.jpg.PNG
# 2023-05-18 01:16:18.782 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12531, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00567.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.783 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00567.jpg.PNG
# 2023-05-18 01:16:18.787 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12532, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00566.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.787 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00566.jpg.PNG
# 2023-05-18 01:16:18.791 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12533, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00565.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.792 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00565.jpg.PNG
# 2023-05-18 01:16:18.796 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12534, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00564.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.796 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00564.jpg.PNG
# 2023-05-18 01:16:18.800 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12535, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00563.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.800 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00563.jpg.PNG
# 2023-05-18 01:16:18.804 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12536, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00562.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.805 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00562.jpg.PNG
# 2023-05-18 01:16:18.809 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12537, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00561.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.810 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00561.jpg.PNG
# 2023-05-18 01:16:18.814 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12538, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00560.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.815 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00560.jpg.PNG
# 2023-05-18 01:16:18.819 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12539, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00559.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.820 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00559.jpg.PNG
# 2023-05-18 01:16:18.824 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12540, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00558.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.825 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00558.jpg.PNG
# 2023-05-18 01:16:18.829 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12541, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00557.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.829 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00557.jpg.PNG
# 2023-05-18 01:16:18.833 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12542, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00556.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.834 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00556.jpg.PNG
# 2023-05-18 01:16:18.838 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12543, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00555.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.839 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00555.jpg.PNG
# 2023-05-18 01:16:18.843 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12544, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00554.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.843 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00554.jpg.PNG
# 2023-05-18 01:16:18.847 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12545, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00553.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.848 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00553.jpg.PNG
# 2023-05-18 01:16:18.851 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12546, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00552.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.852 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00552.jpg.PNG
# 2023-05-18 01:16:18.855 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12547, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00551.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.856 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00551.jpg.PNG
# 2023-05-18 01:16:18.860 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12548, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00550.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.860 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00550.jpg.PNG
# 2023-05-18 01:16:18.864 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12549, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00549.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.865 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00549.jpg.PNG
# 2023-05-18 01:16:18.869 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12550, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00548.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.869 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00548.jpg.PNG
# 2023-05-18 01:16:18.873 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12551, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00547.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.874 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00547.jpg.PNG
# 2023-05-18 01:16:18.878 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12552, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00546.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.878 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00546.jpg.PNG
# 2023-05-18 01:16:18.882 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12553, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00545.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.883 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00545.jpg.PNG
# 2023-05-18 01:16:18.887 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12554, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00544.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.887 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00544.jpg.PNG
# 2023-05-18 01:16:18.891 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12555, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00543.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.892 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00543.jpg.PNG
# 2023-05-18 01:16:18.895 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12556, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00542.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.896 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00542.jpg.PNG
# 2023-05-18 01:16:18.900 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12557, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00541.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.901 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00541.jpg.PNG
# 2023-05-18 01:16:18.904 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12558, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00540.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.905 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00540.jpg.PNG
# 2023-05-18 01:16:18.909 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12559, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00539.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.909 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00539.jpg.PNG
# 2023-05-18 01:16:18.913 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12560, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00538.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.914 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00538.jpg.PNG
# 2023-05-18 01:16:18.918 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12561, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00537.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.918 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00537.jpg.PNG
# 2023-05-18 01:16:18.922 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12562, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00536.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:18.924 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00536.jpg.PNG
# 2023-05-18 01:16:18.928 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 12563, 'width': 512, 'height': 512, 'file_name': 'images/Tx032D_Vensoubor_00535.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# ...
# 2023-05-18 01:16:26.596 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00022.jpg.PNG
# 2023-05-18 01:16:26.600 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1053, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00021.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.600 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00021.jpg.PNG
# 2023-05-18 01:16:26.604 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1054, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00020.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.605 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00020.jpg.PNG
# 2023-05-18 01:16:26.608 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1055, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00019.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.609 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00019.jpg.PNG
# 2023-05-18 01:16:26.613 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1056, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00018.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.614 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00018.jpg.PNG
# 2023-05-18 01:16:26.617 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1057, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00017.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.618 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00017.jpg.PNG
# 2023-05-18 01:16:26.621 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1058, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00016.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.622 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00016.jpg.PNG
# 2023-05-18 01:16:26.625 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1059, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00015.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.626 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00015.jpg.PNG
# 2023-05-18 01:16:26.630 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1060, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00014.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.630 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00014.jpg.PNG
# 2023-05-18 01:16:26.634 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1061, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00013.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.634 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00013.jpg.PNG
# 2023-05-18 01:16:26.639 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1062, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00012.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.640 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00012.jpg.PNG
# 2023-05-18 01:16:26.643 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1063, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00011.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.645 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00011.jpg.PNG
# 2023-05-18 01:16:26.649 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1064, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00010.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.650 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00010.jpg.PNG
# 2023-05-18 01:16:26.653 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1065, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00009.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.654 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00009.jpg.PNG
# 2023-05-18 01:16:26.658 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1066, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00008.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.659 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00008.jpg.PNG
# 2023-05-18 01:16:26.663 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1067, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00007.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.664 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00007.jpg.PNG
# 2023-05-18 01:16:26.668 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1068, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00006.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.669 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00006.jpg.PNG
# 2023-05-18 01:16:26.673 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1069, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00005.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.673 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00005.jpg.PNG
# 2023-05-18 01:16:26.677 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1070, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00004.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.677 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00004.jpg.PNG
# 2023-05-18 01:16:26.681 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1071, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00003.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.682 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00003.jpg.PNG
# 2023-05-18 01:16:26.687 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1072, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00002.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.687 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00002.jpg.PNG
# 2023-05-18 01:16:26.691 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1073, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00001.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.691 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00001.jpg.PNG
# 2023-05-18 01:16:26.695 | DEBUG    | __main__:coco_to_mask:175 - imgName={'id': 1074, 'width': 512, 'height': 512, 'file_name': 'Tx044D_Ven/Tx044D_Vensoubor_00000.jpg', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}
# 2023-05-18 01:16:26.696 | DEBUG    | __main__:coco_to_mask:178 - image_path=D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00000.jpg.PNG
# 2023-05-18 01:16:26.700 | DEBUG    | __main__:coco_to_mask:184 - iM407
# 2023-05-18 01:16:26.706 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00485.jpg.PNG
# 2023-05-18 01:16:26.734 | DEBUG    | __main__:coco_to_mask:184 - iM408
# 2023-05-18 01:16:26.745 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00484.jpg.PNG
# 2023-05-18 01:16:26.770 | DEBUG    | __main__:coco_to_mask:184 - iM409
# 2023-05-18 01:16:26.775 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00483.jpg.PNG
# 2023-05-18 01:16:26.797 | DEBUG    | __main__:coco_to_mask:184 - iM410
# 2023-05-18 01:16:26.803 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00482.jpg.PNG
# 2023-05-18 01:16:26.827 | DEBUG    | __main__:coco_to_mask:184 - iM411
# 2023-05-18 01:16:26.833 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00481.jpg.PNG
# 2023-05-18 01:16:26.859 | DEBUG    | __main__:coco_to_mask:184 - iM505
# 2023-05-18 01:16:26.863 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00356.jpg.PNG
# 2023-05-18 01:16:26.884 | DEBUG    | __main__:coco_to_mask:184 - iM508
# 2023-05-18 01:16:26.888 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00353.jpg.PNG
# 2023-05-18 01:16:26.910 | DEBUG    | __main__:coco_to_mask:184 - iM506
# 2023-05-18 01:16:26.914 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00355.jpg.PNG
# 2023-05-18 01:16:26.936 | DEBUG    | __main__:coco_to_mask:184 - iM507
# 2023-05-18 01:16:26.940 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00354.jpg.PNG
# 2023-05-18 01:16:26.962 | DEBUG    | __main__:coco_to_mask:184 - iM503
# 2023-05-18 01:16:26.967 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx044D_Vensoubor_00358.jpg.PNG
# 2023-05-18 01:16:26.992 | DEBUG    | __main__:coco_to_mask:184 - iM12660
# 2023-05-18 01:16:26.996 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00438.jpg.PNG
# 2023-05-18 01:16:27.016 | DEBUG    | __main__:coco_to_mask:184 - iM12661
# 2023-05-18 01:16:27.020 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00437.jpg.PNG
# 2023-05-18 01:16:27.038 | DEBUG    | __main__:coco_to_mask:184 - iM12662
# 2023-05-18 01:16:27.042 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00436.jpg.PNG
# 2023-05-18 01:16:27.062 | DEBUG    | __main__:coco_to_mask:184 - iM12663
# 2023-05-18 01:16:27.066 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00435.jpg.PNG
# 2023-05-18 01:16:27.084 | DEBUG    | __main__:coco_to_mask:184 - iM12664
# 2023-05-18 01:16:27.088 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00434.jpg.PNG
# 2023-05-18 01:16:27.107 | DEBUG    | __main__:coco_to_mask:184 - iM12665
# 2023-05-18 01:16:27.111 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00433.jpg.PNG
# 2023-05-18 01:16:27.130 | DEBUG    | __main__:coco_to_mask:184 - iM12666
# 2023-05-18 01:16:27.135 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00432.jpg.PNG
# 2023-05-18 01:16:27.154 | DEBUG    | __main__:coco_to_mask:184 - iM12667
# 2023-05-18 01:16:27.158 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00431.jpg.PNG
# 2023-05-18 01:16:27.177 | DEBUG    | __main__:coco_to_mask:184 - iM12668
# 2023-05-18 01:16:27.182 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00430.jpg.PNG
# 2023-05-18 01:16:27.202 | DEBUG    | __main__:coco_to_mask:184 - iM12669
# 2023-05-18 01:16:27.206 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00429.jpg.PNG
# 2023-05-18 01:16:27.228 | DEBUG    | __main__:coco_to_mask:184 - iM12670
# 2023-05-18 01:16:27.232 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00428.jpg.PNG
# 2023-05-18 01:16:27.252 | DEBUG    | __main__:coco_to_mask:184 - iM12671
# 2023-05-18 01:16:27.256 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00427.jpg.PNG
# 2023-05-18 01:16:27.278 | DEBUG    | __main__:coco_to_mask:184 - iM12672
# 2023-05-18 01:16:27.282 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00426.jpg.PNG
# 2023-05-18 01:16:27.308 | DEBUG    | __main__:coco_to_mask:184 - iM12673
# 2023-05-18 01:16:27.313 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00425.jpg.PNG
# 2023-05-18 01:16:27.331 | DEBUG    | __main__:coco_to_mask:184 - iM12674
# 2023-05-18 01:16:27.336 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00424.jpg.PNG
# 2023-05-18 01:16:27.355 | DEBUG    | __main__:coco_to_mask:184 - iM12675
# 2023-05-18 01:16:27.359 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00423.jpg.PNG
# 2023-05-18 01:16:27.378 | DEBUG    | __main__:coco_to_mask:184 - iM12676
# 2023-05-18 01:16:27.380 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00422.jpg.PNG
# 2023-05-18 01:16:27.399 | DEBUG    | __main__:coco_to_mask:184 - iM12677
# 2023-05-18 01:16:27.404 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00421.jpg.PNG
# 2023-05-18 01:16:27.426 | DEBUG    | __main__:coco_to_mask:184 - iM12678
# 2023-05-18 01:16:27.432 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00420.jpg.PNG
# 2023-05-18 01:16:27.453 | DEBUG    | __main__:coco_to_mask:184 - iM12679
# 2023-05-18 01:16:27.458 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00419.jpg.PNG
# 2023-05-18 01:16:27.482 | DEBUG    | __main__:coco_to_mask:184 - iM12680
# 2023-05-18 01:16:27.491 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00418.jpg.PNG
# 2023-05-18 01:16:27.511 | DEBUG    | __main__:coco_to_mask:184 - iM12681
# 2023-05-18 01:16:27.518 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00417.jpg.PNG
# 2023-05-18 01:16:27.539 | DEBUG    | __main__:coco_to_mask:184 - iM12682
# 2023-05-18 01:16:27.545 | DEBUG    | __main__:coco_to_mask:197 - D:\Experimenty\Masky\Validace\Liver\MaskOfPig_Tx032D_Vensoubor_00416.jpg.PNG
